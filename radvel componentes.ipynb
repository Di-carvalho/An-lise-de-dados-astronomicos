# %% [markdown]
# # Análise Filtro I

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Espectroscopia

# %% [markdown]
# # Hb

# %%
# Lendo o arquivo.

radvel = pd.read_csv('componentes_hb.txt', sep = ' ', index_col = False)
radvel
# Out:
#       broad         fluxb   equb  fwhmb   narrow         fluxn   equn  fwhmn
# 0   4863.70  3.430000e-15 -18.57  15.78  4858.01  6.050000e-16  -3.29   4.04
# 1   4871.25  1.850000e-15 -16.64  18.26  4866.07  1.230000e-15 -11.08   8.70
# 2   4866.06  3.000000e-15 -22.00  13.81  4857.48  7.240000e-16  -5.38  13.15
# 3   4860.09  4.470000e-15 -21.17  13.33  4847.21  1.220000e-15  -5.74  15.24
# 4   4855.44  2.890000e-15 -16.88  15.95  4860.53  1.270000e-15  -7.42  14.02
# 5   4863.46  3.140000e-15 -23.29  18.03  4857.64  8.520000e-16  -6.33   5.63
# 6   4866.46  2.610000e-15 -28.26  14.05  4884.95  6.360000e-15  -6.95  21.59
# 7   4865.40  2.910000e-15 -19.54  11.89  4855.70  9.010000e-16  -6.08  13.92
# 8   4860.58  3.080000e-15 -15.72  12.25  4849.55  1.560000e-15  -7.99  19.00
# 9   4853.06  2.060000e-15 -12.85  10.80  4861.75  1.350000e-15  -8.45   8.33
# 10  4864.48  1.810000e-15 -23.12  12.44  4874.35  3.040000e-15  -3.82  14.56
# 11  4866.24  2.090000e-15 -13.92   9.07  4857.22  1.290000e-15  -8.64  12.24
# 12  4861.29  2.100000e-15 -18.12  10.69  4848.15  5.030000e-16  -4.34  10.48
# 13  4856.56  3.580000e-15 -21.96  11.53  4844.96  2.750000e-16  -1.69   7.58
# 14  4861.52  1.560000e-15 -12.64   8.34  4869.65  1.510000e-15 -12.22  19.58
# 15  4867.16  2.250000e-15 -28.83  10.36  4877.11  2.210000e-16  -2.82  12.65
# 16  4863.23  1.780000e-15 -19.63  12.93  4870.53  4.700000e-16  -5.15  14.43

# %%
# Calcula as velocidades radiais.

from astropy.constants import c

radvel['radvel_broad']  = ((radvel['broad'] - 4861.35)/4861.35)*(c.to('km/s'))
radvel['radvel_narrow'] = ((radvel['narrow'] - 4861.35)/4861.35)*(c.to('km/s'))

#radvel.sort_values(by = 'fase')

# %%
# Coloca o bjd no arquivo.

radvel['time'] = pd.read_csv('bjd.txt')

# %%
# Calculo da fase

radvel['fase'] = ((radvel['time'] -2456980.6726) /0.07918 ) % 1

# Duplica a fase.

radvel1 = radvel.copy()
radvel1['fase'] = radvel1['fase'] + 1
radvel = pd.concat([radvel, radvel1], ignore_index=True)

# %%
#Plota o gráfico das velocidades radiais.

f, ax = plt.subplots(figsize=(12,7))

plt.scatter(radvel['fase'], radvel['radvel_broad'], color = 'blue',s = 5)
plt.scatter(radvel['fase'], radvel['radvel_narrow'], color = 'red', s = 5)

# %%
# Plota os gráficos do fluxo.

f, ax = plt.subplots(figsize=(12,7))

radvel = radvel.sort_values(by = 'fase')

plt.plot(radvel['fase'], radvel['fluxb'], color = 'blue')
plt.plot(radvel['fase'], radvel['fluxn'], color = 'red')

# %%
# Plota os Gráficos da largura a meia altura.

f, ax = plt.subplots(figsize=(12,7))


plt.plot(radvel['fase'], radvel['fwhmb'], color = 'blue')
plt.plot(radvel['fase'], radvel['fwhmn'], color = 'red')

# %%
# Plota os gráficos da largura equivalente.

f, ax = plt.subplots(figsize=(12,7))


plt.plot(radvel['fase'], radvel['equb'], color = 'blue')
plt.plot(radvel['fase'], radvel['equn'], color = 'red')

# %% [markdown]
# ## HeII

# %%
# Lendo o arquivo.

radvel = pd.read_csv('he_II _cor.txt', sep = ' ', index_col = False)
radvel
# Out:
#       broad         fluxb   equb  fwhmb   narrow         fluxn   equn  fwhmn
# 0   4691.67  2.430000e-15 -26.66   8.79  4704.11  9.950000e-16 -10.72  28.98
# 1   4689.18  2.560000e-15 -21.11  11.63  4678.90  2.630000e-16  -2.20   9.96
# 2   4682.94  2.730000e-15 -13.84  10.69  4671.31  6.940000e-16  -3.56   7.14
# 3   4678.59  1.820000e-15 -11.29   8.37  4685.69  7.030000e-16  -4.31   5.08
# 4   4684.33  2.270000e-15 -21.96  11.49  4698.44  1.380000e-15 -13.29  26.30
# 5   4691.52  1.990000e-15 -23.09   9.04  4702.82  4.420000e-16  -5.05  28.67
# 6   4688.62  2.030000e-15 -15.34   9.97  4679.64  4.220000e-16  -3.27  11.78
# 7   4682.74  2.210000e-15 -12.30  10.31  4671.71  5.540000e-16  -3.13   6.42
# 8   4679.70  2.650000e-15 -20.86  13.24  4687.49  4.620000e-16  -3.59  13.48
# 9   4690.44  1.910000e-15 -28.04  11.19  4712.90  2.360000e-16  -3.61  14.25
# 10  4689.12  1.100000e-15  -8.22   8.19  4679.37  9.050000e-16  -6.86  13.26
# 11  4684.55  9.760000e-16  -9.52   8.05  4673.21  4.320000e-16  -4.29   7.98
# 12  4680.94  2.010000e-15 -13.69   7.61  4673.48  4.450000e-16  -3.67   4.60
# 13  4698.51  1.650000e-15 -16.64  29.47  4686.99  1.420000e-15 -14.55   7.84
# 14  4691.06  1.570000e-15 -22.29   6.72  4697.34  3.220000e-16  -4.48   9.49
# 15  4686.29  1.080000e-15 -13.05   8.18  4693.02  5.600000e-16  -6.71   7.29

# %%
# Calcula as velocidades radiais.

from astropy.constants import c

radvel['radvel_broad']  = ((radvel['broad'] - 4685.71)/4685.71)*(c.to('km/s'))
radvel['radvel_narrow'] = ((radvel['narrow'] - 4685.71)/4685.71)*(c.to('km/s'))

radvel
# Out:
#       broad         fluxb   equb  fwhmb   narrow         fluxn   equn  fwhmn  \
# 0   4691.67  2.430000e-15 -26.66   8.79  4704.11  9.950000e-16 -10.72  28.98
# 1   4689.18  2.560000e-15 -21.11  11.63  4678.90  2.630000e-16  -2.20   9.96
# 2   4682.94  2.730000e-15 -13.84  10.69  4671.31  6.940000e-16  -3.56   7.14
# 3   4678.59  1.820000e-15 -11.29   8.37  4685.69  7.030000e-16  -4.31   5.08
# 4   4684.33  2.270000e-15 -21.96  11.49  4698.44  1.380000e-15 -13.29  26.30
# 5   4691.52  1.990000e-15 -23.09   9.04  4702.82  4.420000e-16  -5.05  28.67
# 6   4688.62  2.030000e-15 -15.34   9.97  4679.64  4.220000e-16  -3.27  11.78
# 7   4682.74  2.210000e-15 -12.30  10.31  4671.71  5.540000e-16  -3.13   6.42
# 8   4679.70  2.650000e-15 -20.86  13.24  4687.49  4.620000e-16  -3.59  13.48
# 9   4690.44  1.910000e-15 -28.04  11.19  4712.90  2.360000e-16  -3.61  14.25
# 10  4689.12  1.100000e-15  -8.22   8.19  4679.37  9.050000e-16  -6.86  13.26
# 11  4684.55  9.760000e-16  -9.52   8.05  4673.21  4.320000e-16  -4.29   7.98
# 12  4680.94  2.010000e-15 -13.69   7.61  4673.48  4.450000e-16  -3.67   4.60
# 13  4698.51  1.650000e-15 -16.64  29.47  4686.99  1.420000e-15 -14.55   7.84
# 14  4691.06  1.570000e-15 -22.29   6.72  4697.34  3.220000e-16  -4.48   9.49
# 15  4686.29  1.080000e-15 -13.05   8.18  4693.02  5.600000e-16  -6.71   7.29
#
#     radvel_broad  radvel_narrow
# 0     381.321731    1177.234875
# 1     222.011142    -435.704864
# 2    -177.225033    -921.314250
# 3    -455.538713      -1.279603
# 4     -88.292616     814.467389
# 5     371.724708    1094.700474
# 6     186.182255    -388.359549
# 7    -190.021064    -895.722188
# 8    -384.520739     113.884678
# 9     302.626139    1739.620449
# 10    218.172333    -405.634191
# 11    -74.216981    -799.751953
# 12   -305.185345    -782.477311
# 13    818.946000      81.894600
# 14    342.293836     744.089217
# 15     37.108491     467.694942

# %%
# Coloca o bjd no arquivo.

radvel['time'] = pd.read_csv('bjd_cor.txt')

# %%
# Calculo da fase

radvel['fase'] = ((radvel['time'] - 2456980.6705) /0.07918 ) % 1

# Duplica a fase.

radvel1 = radvel.copy()
radvel1['fase'] = radvel1['fase'] + 1
radvel = pd.concat([radvel, radvel1], ignore_index=True)

# %%
#Plota o gráfico das velocidades radiais.

f, ax = plt.subplots(figsize=(12,7))

plt.scatter(radvel['fase'], radvel['radvel_broad'], color = 'blue',s = 5)
plt.scatter(radvel['fase'], radvel['radvel_narrow'], color = 'red', s = 5)

# %%
# Plota os gráficos do fluxo.

f, ax = plt.subplots(figsize=(12,7))

radvel = radvel.sort_values(by = 'fase')

plt.plot(radvel['fase'], radvel['fluxb'], color = 'blue')
plt.plot(radvel['fase'], radvel['fluxn'], color = 'red')

# %%
# Plota os Gráficos da largura a meia altura.

f, ax = plt.subplots(figsize=(12,7))


plt.plot(radvel['fase'], radvel['fwhmb'], color = 'blue')
plt.plot(radvel['fase'], radvel['fwhmn'], color = 'red')

# %%
# Plota os gráficos da largura equivalente.

f, ax = plt.subplots(figsize=(12,7))


plt.plot(radvel['fase'], radvel['equb'], color = 'blue')
plt.plot(radvel['fase'], radvel['equn'], color = 'red')

# %% [markdown]
# # Polarização

# %%
# Lê o arquivo.

pol = pd.read_csv('pol_nfase_bjd.txt', sep = ' ')

# %%
# PLota o gráfico em função de bjd.

f, ax = plt.subplots(figsize=(16,7))

plt.scatter(pol['bjd'], pol['circ_pol'], color = 'blue', s=5)

# %%
# Calcula a fase.

pol['fase'] = ((pol['bjd'] - 255155.3658)/0.07918) % 1

# Duplica a fase.

pol1 = pol.copy()
pol1['fase'] = pol1['fase'] + 1
pol = pd.concat([pol, pol1], ignore_index=True)

# %%
# PLota pol em função da fase.

f, ax = plt.subplots(figsize=(14,7))
plt.scatter(pol['fase'], pol['circ_pol'], color = 'blue', s=5)

# %% [markdown]
# # Curva de Luz

# %%
luz = pd.read_csv('curva_de_luz_fase.txt', sep = ' ')

# %%
f, ax = plt.subplots(figsize=(14,7))
plt.scatter(luz['bjd'], luz['mag'], color = 'blue', s=5)

# %%
luz['fase'] = ((255155.3658 - luz['bjd'])/0.07918) % 1
luz1 = luz.copy()
luz1['fase'] = luz1['fase'] + 1
luz = pd.concat([luz, luz1], ignore_index=True)

# %%
f, ax = plt.subplots(figsize=(14,7))
plt.scatter(luz['fase'], luz['mag'], color = 'blue', s=5)
